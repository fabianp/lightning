# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from scipy import misc
face = misc.face(gray=True)
face = misc.imresize(face, 20).astype(np.float) / 255.0
plt.imshow(face, cmap=plt.cm.gray)
print(face.shape)
# Out:
# (153, 204)

# %%
from lightning.impl import prox_fast

def tv_norm(x):
    pass
all_cost = []
def callback(x):
    all_cost.append()

# %%
face2 = face.copy()
prox_fast.prox_tv2d(face2, 0.00001, max_iter=20000)
plt.imshow(face2, cmap=plt.cm.gray)
# Out:
# 0.418229045889
# 0.418229263373
# 0.418229314953
# 0.416001770072
# 0.404320881389
# 0.402281282872
# 0.396210078892
# 0.392557661228
# 0.391442213617
# 0.378365884205
# 0.377489681398
# 0.374915609938
# 0.374116487527
# 0.370089614132
# 0.364590474445
# 0.363064130278
# 0.360869288599
# 0.35930102298
# 0.358389706435
# 0.347321224154
# 0.346211801093
# 0.345292960097
# 0.343336829281
# 0.341573323778
# 0.338588694938
# 0.337486670911
# 0.334909942049
# 0.332921464364
# 0.331509304481
# 0.326122276015
# 0.324931914045
# 0.322990883273
# 0.319796030796
# 0.31863174228
# 0.315681054092
# 0.31352742032
# 0.311865230912
# 0.311299063981
# 0.310906972735
# 0.304215392216
# 0.303368766542
# 0.302102627551
# 0.300742921315
# 0.299116400084
# 0.296912147797
# 0.295092673204
# 0.294244978332
# 0.292770838904
# 0.292041403452
# 0.288077133182
# 0.286918302338
# 0.285892505244
# 0.284180536316
# 0.282556769115
# 0.281242774096
# 0.279989290125
# 0.279191455919
# 0.278505347199
# 0.275603053153
# ...

# %%
face
# Out:
# array([[ 0.44705882,  0.50980392,  0.56862745, ...,  0.46666667,
#          0.50588235,  0.5372549 ],
#        [ 0.3254902 ,  0.40784314,  0.48235294, ...,  0.4627451 ,
#          0.5254902 ,  0.57254902],
#        [ 0.26666667,  0.34509804,  0.42745098, ...,  0.46666667,
#          0.5254902 ,  0.56862745],
#        ...,
#        [ 0.38431373,  0.40392157,  0.45490196, ...,  0.56470588,
#          0.56078431,  0.56078431],
#        [ 0.36862745,  0.40784314,  0.47058824, ...,  0.56078431,
#          0.55686275,  0.55686275],
#        [ 0.36862745,  0.41568627,  0.46666667, ...,  0.55686275,
#          0.55294118,  0.54901961]])
